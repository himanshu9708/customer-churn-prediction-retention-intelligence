# %% [markdown]
# # Phase 12 — Testing & CI/CD
# Add automated tests for retention logic and the API health endpoint, then run them locally and in GitHub Actions.

# %% [markdown]
# ## Local validation
# `sh scripts/check_project.sh`
#
# `pytest -q`

# %% [markdown]
# ## CI
# The workflow in `.github/workflows/ci.yml` runs on pushes and pull requests to `main`.
