# %% [markdown]
# # Phase 10 — API & Dashboard Demo
# Serving the champion churn model and retention priorities.

# %% [markdown]
# ## API
# Run from the project root:
#
# `uvicorn api.main:app --reload`
#
# Then open `/docs` to inspect the prediction endpoint.

# %% [markdown]
# ## Dashboard
# Run:
#
# `streamlit run dashboard/app.py`
#
# The dashboard reads Phase 9 retention outputs.
