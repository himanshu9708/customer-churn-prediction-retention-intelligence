# %% [markdown]
# # Phase 9 — Retention Intelligence
# Turn champion-model churn probabilities into risk tiers and transparent intervention recommendations.

# %% [markdown]
# ## Risk tiers
# Critical >= 0.80
#
# High 0.60–0.79
#
# Medium 0.40–0.59
#
# Low < 0.40

# %%
import pandas as pd

df = pd.read_csv('../data/processed/customer_churn_features.csv')
df.shape

# %% [markdown]
# ## Run the retention engine
# Run from the project root after Phase 7 training and Phase 8 evaluation:
#
# `python -m src.retention.retention_engine`

# %% [markdown]
# Recommendations are deliberately rule-based and transparent. Validate them against actual retention campaign outcomes before treating them as optimized business policy.
