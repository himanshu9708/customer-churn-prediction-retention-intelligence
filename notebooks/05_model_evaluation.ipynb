# %% [markdown]
# # Phase 8 — Model Evaluation & Explainability
# Evaluate trained Phase 7 models on the untouched deterministic test split. Do not fit models or preprocessing in this notebook.

# %%
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv('../data/processed/customer_churn_features.csv')
X = df.drop(columns=['Churn'])
y = df['Churn'].astype(int)
_, X_test, _, y_test = train_test_split(X, y, test_size=0.20, stratify=y, random_state=42)
X_test.shape

# %% [markdown]
# ## Evaluation metrics
# Use ROC-AUC, PR-AUC, recall, precision, F1, and threshold analysis. For retention, recall and PR-AUC should receive explicit attention.

# %%
# Run the reproducible evaluation from the project root:
# python -m src.evaluation.evaluate_models

# %% [markdown]
# ## Threshold selection
# A 0.50 threshold is only a baseline. The final threshold should reflect retention capacity and the business cost of false negatives versus false positives.
