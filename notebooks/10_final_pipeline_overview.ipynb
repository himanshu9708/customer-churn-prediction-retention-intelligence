# %% [markdown]
# # Phase 13 — Final Integration
# This notebook documents the final end-to-end architecture and reproducibility workflow.

# %% [markdown]
# ## End-to-end command
# From the project root:
#
# `python scripts/run_pipeline.py`

# %% [markdown]
# ## Validation
# Run:
#
# `sh scripts/check_project.sh`
#
# `pytest -q`

# %% [markdown]
# ## Application
# Start FastAPI with `uvicorn api.main:app --reload` and Streamlit with `streamlit run dashboard/app.py`.
